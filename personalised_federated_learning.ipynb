# %% [markdown]
# # Personalised Federated Learning
#
# This is a notebook for the Principles of ML Systems project. Just a scrap pad, don't read too much into it!

# %% [markdown]
# ## Set Up Tensorboard

# %%
from tensorboard import notebook


# %load_ext tensorboard 

# %tensorboard --logdir=./runs --bind_all --port=6006
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-727e44d4cf7abfa0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-727e44d4cf7abfa0");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
from glob import glob
import os
import numpy as np 

for directory,_ , _ in os.walk("./completed_runs"):
    clients_dirs = glob(directory + "/client*/")


    client_accuracies = []
    all_cl_accs = []

    for client_d in clients_dirs:
        event_acc = EventAccumulator(client_d)
        event_acc.Reload()
        # Show all tags in the log file
        # print(event_acc.Tags())
        # E. g. get wall clock, number of steps and value for a scalar 'Accuracy'|
        #print(*event_acc.Scalars('Accuracy/test'))
        _, steps, test_acc = zip(*event_acc.Scalars('Accuracy/test'))
        client_accuracies.append(test_acc[-1])
        all_cl_accs.append(zip(steps,test_acc))

    if client_accuracies:
        print("")
        print(directory)
        #print([ f"{a} {x}" for a,x in all_cl_accs[2]])
        mean = np.mean(client_accuracies)
        std = np.std(client_accuracies)
        x = np.array(client_accuracies)
        idx = (x).argsort()[-2:]
        top2 = np.mean(x[idx])
        idx = (x).argsort()[:2]
        bottom2 = np.mean(x[idx])
         
        print(f'{mean:.3f} & {std:.3f} & {top2 :.3f} & {bottom2 :.3f}')
# Out:
# ./completed_runs/cifar10/qllr=1 q=0.01 alpha=0.01
# 0.509 & 0.097 & 0.623 & 0.405
#
# ./completed_runs/cifar10/qffl  = 1e-2 - same as alpha
# 0.100 & 0.090 & 0.200 & 0.010
#
# ./completed_runs/cifar10/personalisation/before_personalisation/qfed/q=0.1/before_personalisation
# 0.189 & 0.035 & 0.234 & 0.145
#
# ./completed_runs/cifar10/personalisation/before_personalisation/qfed/q=0.01/before_personalisation
# 0.387 & 0.072 & 0.464 & 0.308
#
# ./completed_runs/cifar10/personalisation/before_personalisation/fedavg/round2
# 0.482 & 0.063 & 0.562 & 0.407
#
# ./completed_runs/cifar10/personalisation/before_personalisation/fedavg/round3
# 0.491 & 0.044 & 0.553 & 0.431
#
# ./completed_runs/cifar10/personalisation/before_personalisation/fedavg/round1
# 0.487 & 0.168 & 0.664 & 0.310
#
# ./completed_runs/cifar10/personalisation/after_personalisation/qfed/q=0.1
# 0.151 & 0.137 & 0.301 & 0.012
#
# ./completed_runs/cifar10/personalisation/after_personalisation/qfed/q=0.01
# 0.333 & 0.042 & 0.385 & 0.281
#
# ./completed_runs/cifar10/personalisation/after_personalisation/fedavg/fed trial round
# 0.568 & 0.104 & 0.678 & 0.451
#
# ./completed_runs/cifar10/personalisation/after_personalisation/fedavg/fedavg alpha 0.01
# 0.567 & 0.029 & 0.602 & 0.528
#
# ./completed_runs/cifar10/personalisation/after_personalisation/fedavg/alpha 0.1
# 0.623 & 0.077 & 0.702 & 0.532
#
# ./completed_runs/cifar10/qfflr = 0.1 q = 0.05
# 0.124 & 0.101 & 0.231 & 0.019
#
# ./completed_runs/cifar10/perfedavg/alpha=1e-2 beta=1e-3
# 0.379 & 0.030 & 0.421 & 0.340
#
# ./completed_runs/cifar10/perfedavg/alpha=1e-2 beta =1e-3
# 0.387 & 0.046 & 0.445 & 0.327
#
# ./completed_runs/cifar10/perfedavg/alpha=1e-3 beta=3e-3
# 0.562 & 0.106 & 0.674 & 0.440
#
# ./completed_runs/cifar10/perfedavg/alpha=1e-3 beta=3e-2
# 0.545 & 0.191 & 0.746 & 0.336
#
# ./completed_runs/cifar10/perfedavg/alpha = 1e-3 beta = 1e-2
# 0.551 & 0.035 & 0.602 & 0.509
#
# ./completed_runs/cifar10/qfl 0.2
# 0.118 & 0.020 & 0.144 & 0.093
#
# ./completed_runs/cifar10/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.2/iid_fraction 0.2
# 0.150 & 0.082 & 0.247 & 0.058
#
# ./completed_runs/cifar10/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.2/iid_fraction 0.1
# 0.100 & 0.090 & 0.202 & 0.010
#
# ./completed_runs/cifar10/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.2/iid_fraction 0.5
# 0.142 & 0.032 & 0.177 & 0.104
#
# ./completed_runs/cifar10/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.2/iid_fraction 1.0
# 0.110 & 0.003 & 0.113 & 0.105
#
# ./completed_runs/cifar10/script_outputs/before_personalisation_fedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01_iid_fraction_0.1
# 0.531 & 0.091 & 0.630 & 0.426
#
# ./completed_runs/cifar10/script_outputs/perFedAvg_alpha=1e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# 0.330 & 0.074 & 0.418 & 0.240
#
# ./completed_runs/cifar10/script_outputs/fedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01/iid_fraction 0.2
# 0.575 & 0.018 & 0.604 & 0.553
#
# ./completed_runs/cifar10/script_outputs/fedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01/iid_fraction 0.5
# 0.592 & 0.011 & 0.607 & 0.580
#
# ./completed_runs/cifar10/script_outputs/fedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01/iid_fraction 1.0
# 0.584 & 0.013 & 0.604 & 0.568
#
# ./completed_runs/cifar10/script_outputs/perFedAvgHF_alpha=1e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# 0.336 & 0.112 & 0.463 & 0.210
#
# ./completed_runs/cifar10/script_outputs/perFedAvg_alpha=3e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# 0.324 & 0.047 & 0.373 & 0.245
#
# ./completed_runs/cifar10/script_outputs/perFedAvg_alpha=3e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# 0.278 & 0.063 & 0.358 & 0.186
#
# ./completed_runs/cifar10/script_outputs/perFedAvgHF_alpha=3e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# 0.619 & 0.079 & 0.705 & 0.503
#
# ./completed_runs/cifar10/script_outputs/perFedAvgHF_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# 0.573 & 0.072 & 0.660 & 0.487
#
# ./completed_runs/cifar10/script_outputs/perFedAvgHF_alpha=3e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# 0.397 & 0.142 & 0.553 & 0.246
#
# ./completed_runs/fashionmnist/script_outputs/perFedAvgHF_alpha=3e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# 0.895 & 0.032 & 0.934 & 0.856
#
# ./completed_runs/fashionmnist/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.2
# 0.201 & 0.122 & 0.338 & 0.075
#
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=1e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# 0.729 & 0.057 & 0.789 & 0.660
#
# ./completed_runs/fashionmnist/script_outputs/fedAvg_alpha=1e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# 0.833 & 0.042 & 0.882 & 0.786
#
# ./completed_runs/fashionmnist/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1/iid_fraction 0.2
# 0.200 & 0.148 & 0.354 & 0.035
#
# ./completed_runs/fashionmnist/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1/iid_fraction 0.1
# 0.417 & 0.159 & 0.591 & 0.252
#
# ./completed_runs/fashionmnist/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1/iid_fraction 0.5
# 0.261 & 0.033 & 0.304 & 0.227
#
# ./completed_runs/fashionmnist/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1/iid_fraction 1.0
# 0.215 & 0.008 & 0.224 & 0.204
#
# ./completed_runs/fashionmnist/script_outputs/fedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# 0.874 & 0.050 & 0.933 & 0.814
#
# ./completed_runs/fashionmnist/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# 0.833 & 0.053 & 0.891 & 0.773
#
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=3e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# 0.694 & 0.152 & 0.848 & 0.513
#
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=1e-3_beta=3e-2_numclients=10_q_lr=1_q_param=0.1
# 0.840 & 0.058 & 0.900 & 0.773
#
# ./completed_runs/fashionmnist/script_outputs/perFedAvgHF_alpha=1e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# 0.755 & 0.030 & 0.791 & 0.713
#
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=3e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# 0.424 & 0.081 & 0.532 & 0.308
#
# ./completed_runs/fashionmnist/script_outputs/perFedAvgHF_alpha=3e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# 0.822 & 0.032 & 0.868 & 0.782
#
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=1e-3_beta=3e-3_numclients=10_q_lr=1_q_param=0.1
# 0.785 & 0.035 & 0.825 & 0.744
#
# ./completed_runs/fashionmnist/script_outputs/perFedAvgHF_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# 0.864 & 0.031 & 0.910 & 0.827
#
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=1e-3_beta=1e-2_numclients=10_q_lr=1_q_param=0.1
# 0.815 & 0.098 & 0.917 & 0.706
#
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# 0.595 & 0.072 & 0.694 & 0.509

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
from glob import glob
import os
import numpy as np 
import matplotlib.pyplot as plt

def set_size(fraction=1):
    """Set figure dimensions to avoid scaling in LaTeX.

    Parameters
    ----------
    width: float
            Document textwidth or columnwidth in pts
    fraction: float, optional
            Fraction of the width which you wish the figure to occupy

    Returns
    -------
    fig_dim: tuple
            Dimensions of figure in inches
    """
    width = 397.48499
    
    # Width of figure (in pts)
    fig_width_pt = width * fraction

    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    golden_ratio = (5**.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio

    fig_dim = (fig_width_in, fig_height_in)

    return fig_dim
    
# Using seaborn's style
plt.style.use('seaborn')

# With LaTex fonts
tex_fonts = {
# Use LaTeX to write all text
"text.usetex": False,
"font.family": "serif",
# Use 10pt font in plots, to match 10pt font in document
"axes.labelsize": 10,
"font.size": 10,
# Make the legend/label fonts a little smaller
"legend.fontsize": 8,
"xtick.labelsize": 8,
"ytick.labelsize": 8
}
plt.rcParams.update(tex_fonts)

for directory,_ , _ in os.walk("./completed_runs"):
    clients_dirs = glob(directory + "/client*/")

    

    
    # Initialise figure instance
    test_fig, test_ax = plt.subplots(1, 1, figsize=set_size(0.45))
    train_fig, train_ax = plt.subplots(1, 1, figsize=set_size(0.45))

    # Plot
    test_ax.set_xlim(0, 50)
    test_ax.set_xlabel("Epochs")
    test_ax.set_ylabel("Accuracy (test)")
    
    train_ax.set_xlim(0, 50)
    train_ax.set_xlabel("Epochs")
    train_ax.set_ylabel("Accuracy (train)")
    
    test_accs = []
    train_accs = []

    for client_d in clients_dirs:
        event_acc = EventAccumulator(client_d)
        event_acc.Reload()
        # Show all tags in the log file
        # E. g. get wall clock, number of steps and value for a scalar 'Accuracy'|
        #print(*event_acc.Scalars('Accuracy/test'))
        #_, test_step, test_acc = zip(*event_acc.Scalars('Accuracy/test'))
        #test_accs.append((test_step,test_acc))
        _, train_step, train_acc = zip(*event_acc.Scalars('Accuracy/train'))
        train_accs.append((train_step,train_acc))
        
        
    if test_accs:
        for (x,y) in test_accs:
            test_ax.plot(x, y)
        test_fig.savefig(directory + '/test_acc.pdf', format='pdf', bbox_inches='tight')
    if train_accs:
        for (x,y) in train_accs:
            print(directory)
            train_ax.plot(x, y)
        train_fig.savefig(directory + '/train_acc.pdf', format='pdf', bbox_inches='tight')
    plt.close(train_fig)
    plt.close(test_fig)
# Out:
# ./completed_runs/cifar10/qllr=1 q=0.01 alpha=0.01
# ./completed_runs/cifar10/qffl  = 1e-2 - same as alpha
# ./completed_runs/cifar10/personalisation/before_personalisation/qfed/q=0.1/before_personalisation
# ./completed_runs/cifar10/personalisation/before_personalisation/qfed/q=0.01/before_personalisation
# ./completed_runs/cifar10/personalisation/before_personalisation/fedavg/round2
# ./completed_runs/cifar10/personalisation/before_personalisation/fedavg/round3
# ./completed_runs/cifar10/personalisation/before_personalisation/fedavg/round1
# ./completed_runs/cifar10/personalisation/after_personalisation/qfed/q=0.1
# ./completed_runs/cifar10/personalisation/after_personalisation/qfed/q=0.01
# ./completed_runs/cifar10/personalisation/after_personalisation/fedavg/fed trial round
# ./completed_runs/cifar10/personalisation/after_personalisation/fedavg/fedavg alpha 0.01
# ./completed_runs/cifar10/personalisation/after_personalisation/fedavg/alpha 0.1
# ./completed_runs/cifar10/qfflr = 0.1 q = 0.05
# ./completed_runs/cifar10/perfedavg/alpha=1e-2 beta=1e-3
# ./completed_runs/cifar10/perfedavg/alpha=1e-2 beta =1e-3
# ./completed_runs/cifar10/perfedavg/alpha=1e-3 beta=3e-3
# ./completed_runs/cifar10/perfedavg/alpha=1e-3 beta=3e-2
# ./completed_runs/cifar10/perfedavg/alpha = 1e-3 beta = 1e-2
# ./completed_runs/cifar10/qfl 0.2
# ./completed_runs/cifar10/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.2/iid_fraction 0.2
# ./completed_runs/cifar10/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.2/iid_fraction 0.1
# ./completed_runs/cifar10/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.2/iid_fraction 0.5
# ./completed_runs/cifar10/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.2/iid_fraction 1.0
# ./completed_runs/cifar10/script_outputs/before_personalisation_fedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01_iid_fraction_0.1
# ./completed_runs/cifar10/script_outputs/perFedAvg_alpha=1e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# ./completed_runs/cifar10/script_outputs/fedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01/iid_fraction 0.2
# ./completed_runs/cifar10/script_outputs/fedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01/iid_fraction 0.5
# ./completed_runs/cifar10/script_outputs/fedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01/iid_fraction 1.0
# ./completed_runs/cifar10/script_outputs/perFedAvgHF_alpha=1e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# ./completed_runs/cifar10/script_outputs/perFedAvg_alpha=3e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# ./completed_runs/cifar10/script_outputs/perFedAvg_alpha=3e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# ./completed_runs/cifar10/script_outputs/perFedAvgHF_alpha=3e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# ./completed_runs/cifar10/script_outputs/perFedAvgHF_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# ./completed_runs/cifar10/script_outputs/perFedAvgHF_alpha=3e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# ./completed_runs/fashionmnist/script_outputs/perFedAvgHF_alpha=3e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# ./completed_runs/fashionmnist/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.2
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=1e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# ./completed_runs/fashionmnist/script_outputs/fedAvg_alpha=1e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# ./completed_runs/fashionmnist/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1/iid_fraction 0.2
# ./completed_runs/fashionmnist/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1/iid_fraction 0.1
# ./completed_runs/fashionmnist/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1/iid_fraction 0.5
# ./completed_runs/fashionmnist/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1/iid_fraction 1.0
# ./completed_runs/fashionmnist/script_outputs/fedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# ./completed_runs/fashionmnist/script_outputs/qffedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.01
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=3e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=1e-3_beta=3e-2_numclients=10_q_lr=1_q_param=0.1
# ./completed_runs/fashionmnist/script_outputs/perFedAvgHF_alpha=1e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=3e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# ./completed_runs/fashionmnist/script_outputs/perFedAvgHF_alpha=3e-3_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=1e-3_beta=3e-3_numclients=10_q_lr=1_q_param=0.1
# ./completed_runs/fashionmnist/script_outputs/perFedAvgHF_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=1e-3_beta=1e-2_numclients=10_q_lr=1_q_param=0.1
# ./completed_runs/fashionmnist/script_outputs/perFedAvg_alpha=1e-2_beta=1e-3_numclients=10_q_lr=1_q_param=0.1
