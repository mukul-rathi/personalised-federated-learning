# %% [markdown]
# # Personalised Federated Learning
#
# This is a notebook for the Principles of ML Systems project.

# %% [markdown]
# ## Set Up Tensorboard

# %%
from tensorboard import notebook

directory = './completed_runs/(q)fed_not_personalised/fedavg/'

# %load_ext tensorboard 

# %tensorboard --logdir=./completed_runs --bind_all --port=6006
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-66e5a4d56ad8d488" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-66e5a4d56ad8d488");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
from glob import glob
import os
import numpy as np 

for directory,_ , _ in os.walk("./completed_runs"):
    clients_dirs = glob(directory + "/client*/")


    client_accuracies = []

    for client_d in clients_dirs:
        event_acc = EventAccumulator(client_d)
        event_acc.Reload()
        # Show all tags in the log file
        # print(event_acc.Tags())
        # E. g. get wall clock, number of steps and value for a scalar 'Accuracy'|
        _, _, test_acc = zip(*event_acc.Scalars('Accuracy/test'))
        client_accuracies.append(test_acc[-1])

    if client_accuracies:
        print("")
        print(directory)
        mean = np.mean(client_accuracies)
        std = np.std(client_accuracies)
        print(f'{mean:.3f} \pm {std:.3f}')
# Out:
# ./completed_runs/qfed/qffl lr=0.1 q_param=0.01
# 0.333 \pm 0.042
#
# ./completed_runs/qfed/q_param = 0.1 qffl=0.1
# 0.151 \pm 0.137
#
# ./completed_runs/(q)fed_not_personalised/qfed/qfed 0.01
# 0.387 \pm 0.072
#
# ./completed_runs/(q)fed_not_personalised/qfed/qfl 0.2
# 0.118 \pm 0.020
#
# ./completed_runs/(q)fed_not_personalised/qfed/qFed 0.1
# 0.189 \pm 0.035
#
# ./completed_runs/(q)fed_not_personalised/fedavg/round2
# 0.482 \pm 0.063
#
# ./completed_runs/(q)fed_not_personalised/fedavg/round3
# 0.491 \pm 0.044
#
# ./completed_runs/(q)fed_not_personalised/fedavg/round1
# 0.487 \pm 0.168
#
# ./completed_runs/qffl  = 1e-2 - same as alpha
# 0.100 \pm 0.090
#
# ./completed_runs/qfflr = 0.1 q = 0.05
# 0.124 \pm 0.101
#
# ./completed_runs/perfedavg/alpha=1e-2 beta=1e-3
# 0.379 \pm 0.030
#
# ./completed_runs/perfedavg/alpha=1e-2 beta =1e-3
# 0.387 \pm 0.046
#
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-3
# 0.562 \pm 0.106
#
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-2
# 0.545 \pm 0.191
#
# ./completed_runs/perfedavg/alpha = 1e-3 beta = 1e-2
# 0.551 \pm 0.035
#
# ./completed_runs/fed_after_personalisation/fedavg alpha 0.01
# 0.567 \pm 0.029
#
# ./completed_runs/fed_after_personalisation/alpha 0.1
# 0.623 \pm 0.077
#
# ./completed_runs/fed_after_personalisation/round1
# 0.568 \pm 0.104

# %% [markdown]
# ## Baseline FedAvg CIFAR 10 model

# %%
for root, directory, _ in os.walk("./completed_runs"):
    print(root)
    print(directory)
# Out:
# ./completed_runs
# ['qfed', '(q)fed_not_personalised', '.ipynb_checkpoints', 'qffl  = 1e-2 - same as alpha', 'qfed debuggin', 'qfflr = 0.1 q = 0.05', 'perfedavg', 'fed_after_personalisation']
# ./completed_runs/qfed
# ['qffl lr=0.1 q_param=0.01', 'q_param = 0.1 qffl=0.1']
# ./completed_runs/qfed/qffl lr=0.1 q_param=0.01
# ['federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_5_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_1_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_9_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_2_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_0_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_6_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_4_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_3_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_8_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_7_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/qfed/qffl lr=0.1 q_param=0.01/federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/qfed/qffl lr=0.1 q_param=0.01/client_5_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/qffl lr=0.1 q_param=0.01/client_1_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/qffl lr=0.1 q_param=0.01/client_9_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/qffl lr=0.1 q_param=0.01/client_2_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/qffl lr=0.1 q_param=0.01/client_0_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/qffl lr=0.1 q_param=0.01/client_6_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/qffl lr=0.1 q_param=0.01/client_4_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/qffl lr=0.1 q_param=0.01/client_3_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/qffl lr=0.1 q_param=0.01/client_8_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/qffl lr=0.1 q_param=0.01/client_7_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/q_param = 0.1 qffl=0.1
# ['federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_5_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_1_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_9_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_2_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_0_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_6_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_4_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_3_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_8_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_7_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/qfed/q_param = 0.1 qffl=0.1/federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/qfed/q_param = 0.1 qffl=0.1/client_5_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/q_param = 0.1 qffl=0.1/client_1_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/q_param = 0.1 qffl=0.1/client_9_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/q_param = 0.1 qffl=0.1/client_2_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/q_param = 0.1 qffl=0.1/client_0_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/q_param = 0.1 qffl=0.1/client_6_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/q_param = 0.1 qffl=0.1/client_4_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/q_param = 0.1 qffl=0.1/client_3_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/q_param = 0.1 qffl=0.1/client_8_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed/q_param = 0.1 qffl=0.1/client_7_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised
# ['qfed', 'fedavg']
# ./completed_runs/(q)fed_not_personalised/qfed
# ['qfed 0.01', 'qfl 0.2', 'qFed 0.1']
# ./completed_runs/(q)fed_not_personalised/qfed/qfed 0.01
# ['client_4_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_5_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_3_qffedAvg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_2_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_1_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_0_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_7_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_8_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_9_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_6_qffedAvg_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/(q)fed_not_personalised/qfed/qfed 0.01/client_4_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfed 0.01/client_5_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfed 0.01/client_3_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfed 0.01/federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfed 0.01/client_2_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfed 0.01/client_1_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfed 0.01/client_0_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfed 0.01/client_7_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfed 0.01/client_8_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfed 0.01/client_9_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfed 0.01/client_6_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfl 0.2
# ['client_4_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_5_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_3_qffedAvg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_2_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_1_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_0_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_7_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_8_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_9_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_6_qffedAvg_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/(q)fed_not_personalised/qfed/qfl 0.2/client_4_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfl 0.2/client_5_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfl 0.2/client_3_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfl 0.2/federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfl 0.2/client_2_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfl 0.2/client_1_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfl 0.2/client_0_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfl 0.2/client_7_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfl 0.2/client_8_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfl 0.2/client_9_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qfl 0.2/client_6_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qFed 0.1
# ['client_4_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_5_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_3_qffedAvg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_2_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_1_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_0_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_7_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_8_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_9_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_6_qffedAvg_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/(q)fed_not_personalised/qfed/qFed 0.1/client_4_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qFed 0.1/client_5_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qFed 0.1/client_3_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qFed 0.1/federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qFed 0.1/client_2_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qFed 0.1/client_1_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qFed 0.1/client_0_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qFed 0.1/client_7_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qFed 0.1/client_8_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qFed 0.1/client_9_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/qfed/qFed 0.1/client_6_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg
# ['.ipynb_checkpoints', 'round2', 'round3', 'round1']
# ./completed_runs/(q)fed_not_personalised/fedavg/.ipynb_checkpoints
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round2
# ['client_9_fedavg_federated_10_clients_iid-fraction_0.1', 'client_4_fedavg_federated_10_clients_iid-fraction_0.1', 'client_1_fedavg_federated_10_clients_iid-fraction_0.1', 'client_2_fedavg_federated_10_clients_iid-fraction_0.1', 'client_0_fedavg_federated_10_clients_iid-fraction_0.1', 'client_3_fedavg_federated_10_clients_iid-fraction_0.1', 'client_6_fedavg_federated_10_clients_iid-fraction_0.1', 'client_7_fedavg_federated_10_clients_iid-fraction_0.1', 'client_8_fedavg_federated_10_clients_iid-fraction_0.1', 'client_5_fedavg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_fedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5']
# ./completed_runs/(q)fed_not_personalised/fedavg/round2/client_9_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round2/client_4_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round2/client_1_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round2/client_2_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round2/client_0_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round2/client_3_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round2/client_6_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round2/client_7_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round2/client_8_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round2/client_5_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round2/federated_strategy_fedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round3
# ['.ipynb_checkpoints', 'client_0_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_2_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_8_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_7_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_9_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_1_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_4_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_3_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_6_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_5_fedAvg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_fedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5']
# ./completed_runs/(q)fed_not_personalised/fedavg/round3/.ipynb_checkpoints
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round3/client_0_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round3/client_2_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round3/client_8_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round3/client_7_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round3/client_9_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round3/client_1_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round3/client_4_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round3/client_3_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round3/client_6_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round3/client_5_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round3/federated_strategy_fedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round1
# ['client_9_fedavg_federated_10_clients_iid-fraction_0.1', 'client_4_fedavg_federated_10_clients_iid-fraction_0.1', '.ipynb_checkpoints', 'client_1_fedavg_federated_10_clients_iid-fraction_0.1', 'client_2_fedavg_federated_10_clients_iid-fraction_0.1', 'client_0_fedavg_federated_10_clients_iid-fraction_0.1', 'client_3_fedavg_federated_10_clients_iid-fraction_0.1', 'client_6_fedavg_federated_10_clients_iid-fraction_0.1', 'client_7_fedavg_federated_10_clients_iid-fraction_0.1', 'client_8_fedavg_federated_10_clients_iid-fraction_0.1', 'client_5_fedavg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_fedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5']
# ./completed_runs/(q)fed_not_personalised/fedavg/round1/client_9_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round1/client_4_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round1/.ipynb_checkpoints
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round1/client_1_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round1/client_2_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round1/client_0_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round1/client_3_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round1/client_6_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round1/client_7_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round1/client_8_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round1/client_5_fedavg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/(q)fed_not_personalised/fedavg/round1/federated_strategy_fedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/.ipynb_checkpoints
# []
# ./completed_runs/qffl  = 1e-2 - same as alpha
# ['client_5_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_1_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_2_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_9_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_7_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_3_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_0_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_6_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_8_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_4_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/qffl  = 1e-2 - same as alpha/client_5_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qffl  = 1e-2 - same as alpha/client_1_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qffl  = 1e-2 - same as alpha/client_2_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qffl  = 1e-2 - same as alpha/federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/qffl  = 1e-2 - same as alpha/client_9_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qffl  = 1e-2 - same as alpha/client_7_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qffl  = 1e-2 - same as alpha/client_3_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qffl  = 1e-2 - same as alpha/client_0_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qffl  = 1e-2 - same as alpha/client_6_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qffl  = 1e-2 - same as alpha/client_8_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qffl  = 1e-2 - same as alpha/client_4_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin
# ['qfed not converging', 'converging again!']
# ./completed_runs/qfed debuggin/qfed not converging
# ['foo', 'idk', '.ipynb_checkpoints', 'something else', 'baselines']
# ./completed_runs/qfed debuggin/qfed not converging/foo
# ['client_4_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_5_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_3_qffedAvg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_2_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_1_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_0_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_7_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_8_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_9_qffedAvg_federated_10_clients_iid-fraction_0.1', 'client_6_qffedAvg_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/qfed debuggin/qfed not converging/foo/client_4_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/foo/client_5_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/foo/client_3_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/foo/federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/qfed debuggin/qfed not converging/foo/client_2_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/foo/client_1_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/foo/client_0_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/foo/client_7_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/foo/client_8_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/foo/client_9_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/foo/client_6_qffedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/idk
# ['client_5_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_1_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_2_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_9_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_7_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_3_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_0_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_6_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_8_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_4_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/qfed debuggin/qfed not converging/idk/client_5_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/idk/client_1_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/idk/client_2_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/idk/federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/qfed debuggin/qfed not converging/idk/client_9_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/idk/client_7_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/idk/client_3_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/idk/client_0_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/idk/client_6_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/idk/client_8_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/idk/client_4_qffedAvg_alpha=1e-2_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/.ipynb_checkpoints
# []
# ./completed_runs/qfed debuggin/qfed not converging/something else
# ['federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_5_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_1_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_9_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_2_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_0_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_6_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_4_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_3_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_8_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_7_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/qfed debuggin/qfed not converging/something else/federated_strategy_qffedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/qfed debuggin/qfed not converging/something else/client_5_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/something else/client_1_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/something else/client_9_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/something else/client_2_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/something else/client_0_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/something else/client_6_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/something else/client_4_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/something else/client_3_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/something else/client_8_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/something else/client_7_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines
# ['client_1_qffedAvg_federated_5_clients_iid-fraction_1.0', 'client_3_qffedAvg_federated_5_clients_iid-fraction_1.0', 'client_2_qffedAvg_federated_5_clients_iid-fraction_1.0', 'client_4_fedAvg_federated_5_clients_iid-fraction_1.0', 'federated_strategy_perFedAvg_rounds_10_epochs_1_min_num_clients_5_min_sample_size_5_sample_fraction_1.0', '.ipynb_checkpoints', 'client_1_fedAvg_federated_5_clients_iid-fraction_1.0', 'federated_strategy_fedAvg_rounds_10_epochs_1_min_num_clients_5_min_sample_size_5_sample_fraction_1.0', 'client_4_qffedAvg_federated_5_clients_iid-fraction_1.0', 'client_2_Fedavg_federated_5_clients_iid-fraction_1.0', 'client_4_perFedAvg_federated_5_clients_iid-fraction_1.0', 'client_3_perFedAvg_federated_5_clients_iid-fraction_1.0', 'client_0_perFedAvg_federated_5_clients_iid-fraction_1.0', 'client_2_fedAvg_federated_5_clients_iid-fraction_1.0', 'client_2_perFedAvg_federated_5_clients_iid-fraction_1.0', 'client_1_perFedAvg_federated_5_clients_iid-fraction_1.0', 'client_0_fedAvg_federated_5_clients_iid-fraction_1.0', 'client_3_fedAvg_federated_5_clients_iid-fraction_1.0', 'federated_strategy_qffedAvg_rounds_10_epochs_1_min_num_clients_5_min_sample_size_5_sample_fraction_1.0', 'client_0_qffedAvg_federated_5_clients_iid-fraction_1.0']
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_1_qffedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_3_qffedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_2_qffedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_4_fedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/federated_strategy_perFedAvg_rounds_10_epochs_1_min_num_clients_5_min_sample_size_5_sample_fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/.ipynb_checkpoints
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_1_fedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/federated_strategy_fedAvg_rounds_10_epochs_1_min_num_clients_5_min_sample_size_5_sample_fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_4_qffedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_2_Fedavg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_4_perFedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_3_perFedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_0_perFedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_2_fedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_2_perFedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_1_perFedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_0_fedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_3_fedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/federated_strategy_qffedAvg_rounds_10_epochs_1_min_num_clients_5_min_sample_size_5_sample_fraction_1.0
# []
# ./completed_runs/qfed debuggin/qfed not converging/baselines/client_0_qffedAvg_federated_5_clients_iid-fraction_1.0
# []
# ./completed_runs/qfed debuggin/converging again!
# ['client_5_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_1_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_9_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_2_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_0_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_6_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_4_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_3_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_8_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_7_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/qfed debuggin/converging again!/client_5_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/converging again!/client_1_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/converging again!/client_9_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/converging again!/client_2_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/converging again!/client_0_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/converging again!/client_6_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/converging again!/client_4_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/converging again!/client_3_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/converging again!/client_8_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfed debuggin/converging again!/client_7_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfflr = 0.1 q = 0.05
# ['client_5_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_1_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_9_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_2_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_0_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_6_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_4_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_3_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_8_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1', 'client_7_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/qfflr = 0.1 q = 0.05/client_5_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfflr = 0.1 q = 0.05/client_1_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfflr = 0.1 q = 0.05/client_9_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfflr = 0.1 q = 0.05/client_2_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfflr = 0.1 q = 0.05/client_0_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfflr = 0.1 q = 0.05/client_6_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfflr = 0.1 q = 0.05/client_4_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfflr = 0.1 q = 0.05/client_3_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfflr = 0.1 q = 0.05/client_8_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/qfflr = 0.1 q = 0.05/client_7_qffedAvg_alpha=1e-3_beta=1e-3_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg
# ['alpha=1e-2 beta=1e-3', '.ipynb_checkpoints', 'alpha=1e-2 beta =1e-3', 'alpha=1e-3 beta=3e-3', 'alpha=1e-3 beta=3e-2', 'alpha = 1e-3 beta = 1e-2']
# ./completed_runs/perfedavg/alpha=1e-2 beta=1e-3
# ['client_8_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_9_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_7_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_4_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_3_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_0_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_2_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_1_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_6_perFedAvg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_perFedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_5_perFedAvg_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/perfedavg/alpha=1e-2 beta=1e-3/client_8_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta=1e-3/client_9_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta=1e-3/client_7_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta=1e-3/client_4_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta=1e-3/client_3_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta=1e-3/client_0_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta=1e-3/client_2_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta=1e-3/client_1_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta=1e-3/client_6_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta=1e-3/federated_strategy_perFedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta=1e-3/client_5_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/.ipynb_checkpoints
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta =1e-3
# ['client_8_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_9_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_7_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_4_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_3_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_0_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_2_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_1_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_6_perFedAvg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_perFedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_5_perFedAvg_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/perfedavg/alpha=1e-2 beta =1e-3/client_8_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta =1e-3/client_9_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta =1e-3/client_7_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta =1e-3/client_4_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta =1e-3/client_3_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta =1e-3/client_0_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta =1e-3/client_2_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta =1e-3/client_1_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta =1e-3/client_6_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta =1e-3/federated_strategy_perFedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/perfedavg/alpha=1e-2 beta =1e-3/client_5_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-3
# ['client_0_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_2_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_8_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_7_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_9_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_1_fedAvg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_perFedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_4_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_3_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_6_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_5_fedAvg_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-3/client_0_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-3/client_2_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-3/client_8_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-3/client_7_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-3/client_9_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-3/client_1_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-3/federated_strategy_perFedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-3/client_4_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-3/client_3_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-3/client_6_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-3/client_5_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-2
# ['client_0_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_2_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_8_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_7_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_9_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_1_fedAvg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_perFedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_4_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_3_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_6_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_5_fedAvg_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-2/client_0_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-2/client_2_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-2/client_8_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-2/client_7_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-2/client_9_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-2/client_1_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-2/federated_strategy_perFedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-2/client_4_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-2/client_3_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-2/client_6_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha=1e-3 beta=3e-2/client_5_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha = 1e-3 beta = 1e-2
# ['client_0_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_2_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_8_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_7_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_9_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_1_fedAvg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_perFedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_4_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_3_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_6_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_5_fedAvg_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/perfedavg/alpha = 1e-3 beta = 1e-2/client_0_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha = 1e-3 beta = 1e-2/client_2_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha = 1e-3 beta = 1e-2/client_8_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha = 1e-3 beta = 1e-2/client_7_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha = 1e-3 beta = 1e-2/client_9_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha = 1e-3 beta = 1e-2/client_1_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha = 1e-3 beta = 1e-2/federated_strategy_perFedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/perfedavg/alpha = 1e-3 beta = 1e-2/client_4_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha = 1e-3 beta = 1e-2/client_3_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha = 1e-3 beta = 1e-2/client_6_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/perfedavg/alpha = 1e-3 beta = 1e-2/client_5_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation
# ['.ipynb_checkpoints', 'fedavg alpha 0.01', 'alpha 0.1', 'round1']
# ./completed_runs/fed_after_personalisation/.ipynb_checkpoints
# []
# ./completed_runs/fed_after_personalisation/fedavg alpha 0.01
# ['client_0_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_2_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_8_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_7_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_9_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_1_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_4_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_3_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_6_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_5_fedAvg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_fedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5']
# ./completed_runs/fed_after_personalisation/fedavg alpha 0.01/client_0_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/fedavg alpha 0.01/client_2_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/fedavg alpha 0.01/client_8_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/fedavg alpha 0.01/client_7_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/fedavg alpha 0.01/client_9_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/fedavg alpha 0.01/client_1_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/fedavg alpha 0.01/client_4_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/fedavg alpha 0.01/client_3_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/fedavg alpha 0.01/client_6_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/fedavg alpha 0.01/client_5_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/fedavg alpha 0.01/federated_strategy_fedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/fed_after_personalisation/alpha 0.1
# ['client_8_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_9_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_7_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_4_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_3_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_0_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_2_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_1_perFedAvg_federated_10_clients_iid-fraction_0.1', 'client_6_perFedAvg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_perFedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5', 'client_5_perFedAvg_federated_10_clients_iid-fraction_0.1']
# ./completed_runs/fed_after_personalisation/alpha 0.1/client_8_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/alpha 0.1/client_9_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/alpha 0.1/client_7_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/alpha 0.1/client_4_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/alpha 0.1/client_3_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/alpha 0.1/client_0_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/alpha 0.1/client_2_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/alpha 0.1/client_1_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/alpha 0.1/client_6_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/alpha 0.1/federated_strategy_perFedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
# ./completed_runs/fed_after_personalisation/alpha 0.1/client_5_perFedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/round1
# ['.ipynb_checkpoints', 'client_0_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_2_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_8_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_7_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_9_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_1_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_4_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_3_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_6_fedAvg_federated_10_clients_iid-fraction_0.1', 'client_5_fedAvg_federated_10_clients_iid-fraction_0.1', 'federated_strategy_fedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5']
# ./completed_runs/fed_after_personalisation/round1/.ipynb_checkpoints
# []
# ./completed_runs/fed_after_personalisation/round1/client_0_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/round1/client_2_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/round1/client_8_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/round1/client_7_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/round1/client_9_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/round1/client_1_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/round1/client_4_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/round1/client_3_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/round1/client_6_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/round1/client_5_fedAvg_federated_10_clients_iid-fraction_0.1
# []
# ./completed_runs/fed_after_personalisation/round1/federated_strategy_fedAvg_rounds_10_epochs_5_min_num_clients_5_min_sample_size_5_sample_fraction_0.5
# []
